# %%
from datetime import datetime
import os
import toml
from netCDF4 import Dataset
import xarray as xr

netcdf_path = '/fs/yedoma/home/vpo001/ModImpNet/examples/MODIS_test_Martha/download/Martha_snow_cover_LST_results.nc'

# %%
ncfile = Dataset(netcdf_path)
ncfile
# Out:
# <class 'netCDF4._netCDF4.Dataset'>
# root group (NETCDF4 data model, file format HDF5):
#     Conventions: CF-1.6
#     featureType: timeSeries
#     date_created: 2025-04-01T18:04:49.006342+00:00
#     source: MODIS/Terra Snow Cover Daily L3 Global 500m SIN Grid, Version 61
#  Data set id: MOD10A1.061
#  DOI: 10.5067/MODIS/MOD10A1.061
#  Layer: NDSI_Snow_Cover
#  AND
#  MODIS/Terra Land Surface Temperature/Emissivity Daily L3 Global 1 km SIN Grid, Version 61
#  Data set id: MOD11A1.061
#  DOI: 10.5067/MODIS/MOD11A1.061
#  Layers: LST_Day_1km, LST_Night_1km, Clear_day_cov, Clear_night_cov
#     dimensions(sizes): nchars(32), pointID(2), time(24)
#     variables(dimensions): float64 Date(time), |S1 pointID(pointID, nchars), float64 latitude(pointID), float64 longitude(pointID), |S1 MODIS_Tile(pointID, nchars), float64 NDSI_Snow_Cover(pointID, time), int32 NDSI_Snow_Cover_original_with_code_for_missing_data(pointID, time), float64 LST_Day(pointID, time), float64 LST_Night(pointID, time), float64 Clear_day_cov(pointID, time), float64 Clear_night_cov(pointID, time)
#     groups:

# %%
xrnet = xr.open_dataset('/fs/yedoma/home/vpo001/ModImpNet/examples/MODIS_test_Martha/download/Martha_snow_cover_LST_results.nc', engine="netcdf4")
xrnet
# Out:
# <xarray.Dataset> Size: 2kB
# Dimensions:                                              (time: 24, pointID: 2)
# Coordinates:
#   * pointID                                              (pointID) |S32 64B b...
# Dimensions without coordinates: time
# Data variables:
#     Date                                                 (time) datetime64[ns] 192B ...
#     latitude                                             (pointID) float64 16B ...
#     longitude                                            (pointID) float64 16B ...
#     MODIS_Tile                                           (pointID) object 16B ...
#     NDSI_Snow_Cover                                      (pointID, time) float64 384B ...
#     NDSI_Snow_Cover_original_with_code_for_missing_data  (pointID, time) int32 192B ...
#     LST_Day                                              (pointID, time) float64 384B ...
#     LST_Night                                            (pointID, time) float64 384B ...
#     Clear_day_cov                                        (pointID, time) float64 384B ...
#     Clear_night_cov                                      (pointID, time) float64 384B ...
# Attributes:
#     Conventions:   CF-1.6
#     featureType:   timeSeries
#     date_created:  2025-04-01T18:04:49.006342+00:00
#     source:        MODIS/Terra Snow Cover Daily L3 Global 500m SIN Grid, Vers...

# %%
for var in list(xrnet.variables):
    print(var, xrnet[var].values)
# Out:
# Date ['2000-02-24T00:00:00.000000000' '2000-02-25T00:00:00.000000000'
#  '2000-02-26T00:00:00.000000000' '2000-02-27T00:00:00.000000000'
#  '2000-02-28T00:00:00.000000000' '2000-02-29T00:00:00.000000000'
#  '2000-03-01T00:00:00.000000000' '2000-03-02T00:00:00.000000000'
#  '2000-03-03T00:00:00.000000000' '2000-03-04T00:00:00.000000000'
#  '2000-03-05T00:00:00.000000000' '2000-03-06T00:00:00.000000000'
#  '2000-03-07T00:00:00.000000000' '2000-03-08T00:00:00.000000000'
#  '2000-03-09T00:00:00.000000000' '2000-03-10T00:00:00.000000000'
#  '2000-03-11T00:00:00.000000000' '2000-03-12T00:00:00.000000000'
#  '2000-03-13T00:00:00.000000000' '2000-03-14T00:00:00.000000000'
#  '2000-03-15T00:00:00.000000000' '2000-03-16T00:00:00.000000000'
#  '2000-03-17T00:00:00.000000000' '2000-03-18T00:00:00.000000000']
# pointID [b'Martha_1400' b'Martha_1600']
# latitude [60.685361 60.682103]
# longitude [-137.556814 -137.556094]
# MODIS_Tile [b'h11v02' b'h11v02']
# NDSI_Snow_Cover [[69. 68. nan 86. nan nan nan 48. nan 88. nan nan nan 94. 81. 94. nan 41.
#   nan nan nan nan nan nan]
#  [68. 68. nan 89. nan nan nan 60. nan 87. nan nan 91. 94. 82. nan 36. 74.
#   nan 70. nan nan nan nan]]
# NDSI_Snow_Cover_original_with_code_for_missing_data [[ 69  68 250  86 250 250 255  48 250  88 250 250 201  94  81  94 250  41
#   250 250 255 255 201 250]
#  [ 68  68 250  89 250 250 255  60 201  87 250 250  91  94  82 201  36  74
#   201  70 255 255 201 250]]
# LST_Day [[-10.8700012 -11.9500183 -11.4500183 -10.8500122         nan         nan
#           nan -10.8700012 -12.1900085 -11.7099976         nan         nan
#   -11.6700195 -12.0499939 -10.9500183 -11.8500122         nan -14.2500061
#           nan  -9.9299988         nan         nan         nan         nan]
#  [-12.2300171 -12.9299988 -11.5100159 -13.1900085         nan         nan
#           nan -10.2500061 -15.2500061 -12.7099976 -16.0499939         nan
#   -12.5700134 -12.9899963 -10.3299927 -15.0700134 -14.2500061 -14.0499939
#           nan -10.5499939         nan         nan         nan         nan]]
# LST_Night [[        nan         nan -14.3299927 -14.9100098 -16.3100037         nan
#   -10.8700012 -17.7100128         nan -10.0100159 -15.4100098 -15.2900146
#           nan -18.5300049 -16.2300171 -17.15      -19.6100067         nan
#           nan         nan         nan  -8.5700134 -12.0700134 -10.1099915]
#  [        nan         nan -14.4700073 -14.6700195 -17.0700134         nan
#   -11.4100098 -17.7899994         nan -11.4100098 -15.8100037 -15.4500183
#           nan -18.630011  -16.2099976 -17.1099915 -19.4700073         nan
#           nan         nan         nan  -9.0300049 -10.2900146 -10.3500122]]
# Clear_day_cov [[1.8425001 1.        0.725     1.        0.        0.        0.
#   1.9755001 1.1575    1.021     0.        0.        1.        1.
#   1.        0.9675    0.        0.267     0.        0.312     0.
#   0.        0.        0.       ]
#  [1.6900001 1.        0.5545    0.9985    0.        0.        0.
#   1.2915001 0.063     1.3945    0.5085    0.        1.        1.
#   0.9965001 0.5025    0.202     0.4475    0.        0.9990001 0.
#   0.        0.        0.       ]]
# Clear_night_cov [[0.        0.        1.        0.992     1.        0.        0.172
#   1.        0.        1.        0.9850001 1.        0.        1.
#   0.9760001 1.        0.0635    0.        0.        0.        0.
#   0.998     1.0470001 1.       ]
#  [0.        0.        0.5805    1.0725001 1.        0.        0.497
#   1.        0.        0.998     0.9860001 1.        0.        1.
#   0.9935001 1.        1.4230001 0.        0.        0.        0.
#   0.9990001 0.733     0.9825001]]
